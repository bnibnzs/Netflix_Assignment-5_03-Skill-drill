# %%
# Dependencies
import pandas as pd
import plotly.express as plt
import os
import statsmodels.api as sm
import numpy as np

# %%
#import data
bikecounts_file = os.path.join('Resources', 'bikecounts.csv')
bikecounts_df = pd.read_csv(bikecounts_file)
bikecounts_df['Day'] = pd.to_datetime(bikecounts_df['Day'])
bikecounts_df#.head()
# Out:
#     Unnamed: 0        Date        Day  High Temp (°F)  Low Temp (°F)  \
# 0            0  2016-04-01 2016-04-01            78.1           66.0
# 1            1  2016-04-02 2016-04-02            55.0           48.9
# 2            2  2016-04-03 2016-04-03            39.9           34.0
# 3            3  2016-04-04 2016-04-04            44.1           33.1
# 4            4  2016-04-05 2016-04-05            42.1           26.1
# 5            5  2016-04-06 2016-04-06            45.0           30.0
# 6            6  2016-04-07 2016-04-07            57.0           53.1
# 7            7  2016-04-08 2016-04-08            46.9           44.1
# 8            8  2016-04-09 2016-04-09            43.0           37.9
# 9            9  2016-04-10 2016-04-10            48.9           30.9
# 10          10  2016-04-11 2016-04-11            62.1           46.0
# 11          11  2016-04-12 2016-04-12            57.0           45.0
# 12          12  2016-04-13 2016-04-13            57.0           39.9
# ...

# %%
# Removing symbols/characters and changing  precipitation to float
def clear_characters(number):
    for chara in ['T', '(S)', ' ']:
        number = number.replace(chara, '')
    return number.strip()

# %%
bikecounts_df['Precipitation'] = bikecounts_df['Precipitation'].apply(clear_characters)
bikecounts_df['Precipitation'] = bikecounts_df['Precipitation'].replace('',0).astype('float64')
bikecounts_df#.head()
# Out:
#     Unnamed: 0        Date        Day  High Temp (°F)  Low Temp (°F)  \
# 0            0  2016-04-01 2016-04-01            78.1           66.0
# 1            1  2016-04-02 2016-04-02            55.0           48.9
# 2            2  2016-04-03 2016-04-03            39.9           34.0
# 3            3  2016-04-04 2016-04-04            44.1           33.1
# 4            4  2016-04-05 2016-04-05            42.1           26.1
# 5            5  2016-04-06 2016-04-06            45.0           30.0
# 6            6  2016-04-07 2016-04-07            57.0           53.1
# 7            7  2016-04-08 2016-04-08            46.9           44.1
# 8            8  2016-04-09 2016-04-09            43.0           37.9
# 9            9  2016-04-10 2016-04-10            48.9           30.9
# 10          10  2016-04-11 2016-04-11            62.1           46.0
# 11          11  2016-04-12 2016-04-12            57.0           45.0
# 12          12  2016-04-13 2016-04-13            57.0           39.9
# ...

# %% [markdown]
# HYPOTHESIS:-
# The number of bikes crossing brooklyn bridge is directly proportional to precipitation.
#
# NULL HYPOTHESIS:-
# There is no relation between the precipitation and the number of bikes crossing Brooklyn Bridge.
#
# Test:-
# The test is being performed with an alpha value of 0.05. Hence, a pvalue less than 0.05 will result in the null hypothesis being rejected.

# %%
# Select independent terms, and dependent terms.
dependent_variable = bikecounts_df['Brooklyn Bridge']
independent_variable = bikecounts_df['Precipitation']

X = sm.add_constant(independent_variable)
model = sm.OLS(dependent_variable, X)
results = model.fit()

# %%
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Brooklyn Bridge   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.337
# Method:                 Least Squares   F-statistic:                     15.71
# Date:                Fri, 22 Oct 2021   Prob (F-statistic):           0.000463
# Time:                        20:18:54   Log-Likelihood:                -242.48
# No. Observations:                  30   AIC:                             489.0
# Df Residuals:                      28   BIC:                             491.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const          2571.0184    166.446     15.447      0.000    2230.068    2911.968
# ...

# %% [markdown]
# Result:-
#
# 1)The P-value is found to be from the test 0.000463 which is less than the alpha value. Therefore the null hypothesis can be rejected.
# 2)The R-squared value is positive (0.359) so it can be established that there is a direct relationship between the number of bikes crossing the brooklyn bridge and the precipitation.
